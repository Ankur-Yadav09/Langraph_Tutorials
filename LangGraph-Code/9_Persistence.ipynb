# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
# from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_groq import ChatGroq
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
load_dotenv()
# Out:
# True

# %%
# llm = ChatGoogleGenerativeAI(
#     model="gemini-2.5-flash",
#     temperature=0.7
# )
llm = ChatGroq(model="llama-3.3-70b-versatile")

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'Football'}, config=config1)
# Out:
# {'topic': 'Football',
#  'joke': 'Why did the football go to the doctor?\n\nBecause it was feeling a little "deflated"! (get it?)',
#  'explanation': 'A clever play on words. This joke is funny because it uses a pun to create a humorous connection between the setup and the punchline. Here\'s how it works:\n\nThe joke starts by asking why a football went to the doctor, which sets up the expectation that something is wrong with the football. The punchline "it was feeling a little \'deflated\'" is a clever wordplay on two meanings of the word "deflated":\n\n1. **Emotional state**: In everyday language, "deflated" can mean feeling sad, disheartened, or disappointed. So, in this sense, the football is feeling down or unwell.\n2. **Physical state**: A football, being an inflatable object, can also become deflated if it loses air. This is a common issue with footballs, as they can leak air over time or be intentionally deflated (as in the case of the infamous "Deflategate" scandal in the NFL).\n\nThe joke relies on this double meaning of "deflated" to create a humorous connection between the setup and the punchline. The speaker is making a clever connection between the football\'s emotional state (feeling down) and its physical state (losing air), which creates a lighthearted and amusing effect. The "get it?" at the end of the joke is a nod to the wordplay, inviting the listener to appreciate the cleverness of the pun.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'Football', 'joke': 'Why did the football go to the doctor?\n\nBecause it was feeling a little "deflated"! (get it?)', 'explanation': 'A clever play on words. This joke is funny because it uses a pun to create a humorous connection between the setup and the punchline. Here\'s how it works:\n\nThe joke starts by asking why a football went to the doctor, which sets up the expectation that something is wrong with the football. The punchline "it was feeling a little \'deflated\'" is a clever wordplay on two meanings of the word "deflated":\n\n1. **Emotional state**: In everyday language, "deflated" can mean feeling sad, disheartened, or disappointed. So, in this sense, the football is feeling down or unwell.\n2. **Physical state**: A football, being an inflatable object, can also become deflated if it loses air. This is a common issue with footballs, as they can leak air over time or be intentionally deflated (as in the case of the infamous "Deflategate" scandal in the NFL).\n\nThe joke relies on this double meaning of "deflated" to create a humorous connection between the setup and the punchline. The speaker is making a clever connection between the football\'s emotional state (feeling down) and its physical state (losing air), which creates a lighthearted and amusing effect. The "get it?" at the end of the joke is a nod to the wordplay, inviting the listener to appreciate the cleverness of the pun.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-e405-6fa6-8002-3b392b71779f'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-07-19T09:15:48.546520+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-d92f-6ac2-8001-5d19a295468a'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'Football', 'joke': 'Why did the football go to the doctor?\n\nBecause it was feeling a little "deflated"! (get it?)', 'explanation': 'A clever play on words. This joke is funny because it uses a pun to create a humorous connection between the setup and the punchline. Here\'s how it works:\n\nThe joke starts by asking why a football went to the doctor, which sets up the expectation that something is wrong with the football. The punchline "it was feeling a little \'deflated\'" is a clever wordplay on two meanings of the word "deflated":\n\n1. **Emotional state**: In everyday language, "deflated" can mean feeling sad, disheartened, or disappointed. So, in this sense, the football is feeling down or unwell.\n2. **Physical state**: A football, being an inflatable object, can also become deflated if it loses air. This is a common issue with footballs, as they can leak air over time or be intentionally deflated (as in the case of the infamous "Deflategate" scandal in the NFL).\n\nThe joke relies on this double meaning of "deflated" to create a humorous connection between the setup and the punchline. The speaker is making a clever connection between the football\'s emotional state (feeling down) and its physical state (losing air), which creates a lighthearted and amusing effect. The "get it?" at the end of the joke is a nod to the wordplay, inviting the listener to appreciate the cleverness of the pun.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-e405-6fa6-8002-3b392b71779f'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-07-19T09:15:48.546520+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-d92f-6ac2-8001-5d19a295468a'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'Football', 'joke': 'Why did the football go to the doctor?\n\nBecause it was feeling a little "deflated"! (get it?)'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-d92f-6ac2-8001-5d19a295468a'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-07-19T09:15:47.410177+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-d16b-66b6-8000-d7b9a9fc30b6'}}, tasks=(PregelTask(id='a8b56a55-767d-238b-ffa8-7f7ad0d0ef8f', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'A clever play on words. This joke is funny because it uses a pun to create a humorous connection between the setup and the punchline. Here\'s how it works:\n\nThe joke starts by asking why a football went to the doctor, which sets up the expectation that something is wrong with the football. The punchline "it was feeling a little \'deflated\'" is a clever wordplay on two meanings of the word "deflated":\n\n1. **Emotional state**: In everyday language, "deflated" can mean feeling sad, disheartened, or disappointed. So, in this sense, the football is feeling down or unwell.\n2. **Physical state**: A football, being an inflatable object, can also become deflated if it loses air. This is a common issue with footballs, as they can leak air over time or be intentionally deflated (as in the case of the infamous "Deflategate" scandal in the NFL).\n\nThe joke relies on this double meaning of "deflated" to create a humorous connection between the setup and the punchline. The speaker is making a clever connection between the football\'s emotional state (feeling down) and its physical state (losing air), which creates a lighthearted and amusing effect. The "get it?" at the end of the joke is a nod to the wordplay, inviting the listener to appreciate the cleverness of the pun.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'Football'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-d16b-66b6-8000-d7b9a9fc30b6'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-07-19T09:15:46.595791+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-d0ec-6826-bfff-da611d2e77b7'}}, tasks=(PregelTask(id='b95ae5a7-76d4-9566-6cca-b905ce611e6c', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the football go to the doctor?\n\nBecause it was feeling a little "deflated"! (get it?)'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-d0ec-6826-bfff-da611d2e77b7'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-07-19T09:15:46.543810+00:00', parent_config=None, tasks=(PregelTask(id='2296d350-95b5-e1b4-76cb-54651d78bc55', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'Football'}),), interrupts=())]

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'Cricket'}, config=config2)
# Out:
# {'topic': 'Cricket',
#  'joke': 'Why did the cricket go to the doctor?\n\nBecause it had a "sticky" wicket situation and was feeling a little "bowled" over! (get it?)',
#  'explanation': 'A classic joke that combines wordplay with a dash of sports terminology. Here\'s a breakdown of the explanation:\n\nThe joke starts by setting up a familiar scenario: a cricket (the insect) goes to the doctor. The punchline is where the humor kicks in. It says the cricket had a "sticky" wicket situation and was feeling a little "bowled" over.\n\nThe wordplay comes from the fact that "wicket" and "bowled" are terms from the sport of cricket. In cricket, a wicket refers to the set of three stumps and two bails that a batsman defends. A "sticky wicket" is a phrase used to describe a difficult or precarious situation, often originating from the sport where a wet or damp wicket can make it challenging for batsmen to play.\n\nThe phrase "bowled over" is also a cricket term, where a batsman is dismissed when a ball knocks over their wicket. However, in a more general sense, "bowled over" is an idiomatic expression meaning to be overwhelmed, shocked, or surprised.\n\nIn the joke, the cricket (insect) is using these cricket (sport) terms to describe its situation. The humor comes from the unexpected twist of an insect using sports terminology to explain its predicament. The joke relies on a basic understanding of cricket terminology, but the wordplay and clever use of language create a lighthearted and amusing effect.'}

# %%
workflow.get_state(config2)
# Out:
# StateSnapshot(values={'topic': 'Cricket', 'joke': 'Why did the cricket go to the doctor?\n\nBecause it had a "sticky" wicket situation and was feeling a little "bowled" over! (get it?)', 'explanation': 'A classic joke that combines wordplay with a dash of sports terminology. Here\'s a breakdown of the explanation:\n\nThe joke starts by setting up a familiar scenario: a cricket (the insect) goes to the doctor. The punchline is where the humor kicks in. It says the cricket had a "sticky" wicket situation and was feeling a little "bowled" over.\n\nThe wordplay comes from the fact that "wicket" and "bowled" are terms from the sport of cricket. In cricket, a wicket refers to the set of three stumps and two bails that a batsman defends. A "sticky wicket" is a phrase used to describe a difficult or precarious situation, often originating from the sport where a wet or damp wicket can make it challenging for batsmen to play.\n\nThe phrase "bowled over" is also a cricket term, where a batsman is dismissed when a ball knocks over their wicket. However, in a more general sense, "bowled over" is an idiomatic expression meaning to be overwhelmed, shocked, or surprised.\n\nIn the joke, the cricket (insect) is using these cricket (sport) terms to describe its situation. The humor comes from the unexpected twist of an insect using sports terminology to explain its predicament. The joke relies on a basic understanding of cricket terminology, but the wordplay and clever use of language create a lighthearted and amusing effect.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-f168-609f-8002-b6be26a2161d'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-07-19T09:15:49.949850+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-e65e-628f-8001-b169105f8b81'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'Cricket', 'joke': 'Why did the cricket go to the doctor?\n\nBecause it had a "sticky" wicket situation and was feeling a little "bowled" over! (get it?)', 'explanation': 'A classic joke that combines wordplay with a dash of sports terminology. Here\'s a breakdown of the explanation:\n\nThe joke starts by setting up a familiar scenario: a cricket (the insect) goes to the doctor. The punchline is where the humor kicks in. It says the cricket had a "sticky" wicket situation and was feeling a little "bowled" over.\n\nThe wordplay comes from the fact that "wicket" and "bowled" are terms from the sport of cricket. In cricket, a wicket refers to the set of three stumps and two bails that a batsman defends. A "sticky wicket" is a phrase used to describe a difficult or precarious situation, often originating from the sport where a wet or damp wicket can make it challenging for batsmen to play.\n\nThe phrase "bowled over" is also a cricket term, where a batsman is dismissed when a ball knocks over their wicket. However, in a more general sense, "bowled over" is an idiomatic expression meaning to be overwhelmed, shocked, or surprised.\n\nIn the joke, the cricket (insect) is using these cricket (sport) terms to describe its situation. The humor comes from the unexpected twist of an insect using sports terminology to explain its predicament. The joke relies on a basic understanding of cricket terminology, but the wordplay and clever use of language create a lighthearted and amusing effect.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-f168-609f-8002-b6be26a2161d'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-07-19T09:15:49.949850+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-e65e-628f-8001-b169105f8b81'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'Cricket', 'joke': 'Why did the cricket go to the doctor?\n\nBecause it had a "sticky" wicket situation and was feeling a little "bowled" over! (get it?)'}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-e65e-628f-8001-b169105f8b81'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-07-19T09:15:48.792351+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-e498-6ee9-8000-8a0bba4aa45d'}}, tasks=(PregelTask(id='60839cba-9068-5569-987d-4a9dee0cc1df', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'A classic joke that combines wordplay with a dash of sports terminology. Here\'s a breakdown of the explanation:\n\nThe joke starts by setting up a familiar scenario: a cricket (the insect) goes to the doctor. The punchline is where the humor kicks in. It says the cricket had a "sticky" wicket situation and was feeling a little "bowled" over.\n\nThe wordplay comes from the fact that "wicket" and "bowled" are terms from the sport of cricket. In cricket, a wicket refers to the set of three stumps and two bails that a batsman defends. A "sticky wicket" is a phrase used to describe a difficult or precarious situation, often originating from the sport where a wet or damp wicket can make it challenging for batsmen to play.\n\nThe phrase "bowled over" is also a cricket term, where a batsman is dismissed when a ball knocks over their wicket. However, in a more general sense, "bowled over" is an idiomatic expression meaning to be overwhelmed, shocked, or surprised.\n\nIn the joke, the cricket (insect) is using these cricket (sport) terms to describe its situation. The humor comes from the unexpected twist of an insect using sports terminology to explain its predicament. The joke relies on a basic understanding of cricket terminology, but the wordplay and clever use of language create a lighthearted and amusing effect.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'Cricket'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-e498-6ee9-8000-8a0bba4aa45d'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-07-19T09:15:48.606731+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-e496-66fc-bfff-232af77ea444'}}, tasks=(PregelTask(id='6dbb367f-482a-19c5-231c-1ea3aadccc56', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the cricket go to the doctor?\n\nBecause it had a "sticky" wicket situation and was feeling a little "bowled" over! (get it?)'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-e496-66fc-bfff-232af77ea444'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-07-19T09:15:48.605710+00:00', parent_config=None, tasks=(PregelTask(id='bdc88217-8b3c-23d8-2b00-640b89783867', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'Cricket'}),), interrupts=())]

# %% [markdown]
# ### Time Travel

# %%
workflow.get_state({"configurable": {"thread_id": "2", "checkpoint_id": "1f15d969-8ed6-683c-8000-0c7a2f030ccd"}})
# Out:
# StateSnapshot(values={}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_id': '1f15d969-8ed6-683c-8000-0c7a2f030ccd'}}, metadata=None, created_at=None, parent_config=None, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'Cricket', 'joke': 'Why did the cricket go to the doctor?\n\nBecause it had a "sticky" wicket situation and was feeling a little "bowled" over! (get it?)', 'explanation': 'A classic joke that combines wordplay with a dash of sports terminology. Here\'s a breakdown of the explanation:\n\nThe joke starts by setting up a familiar scenario: a cricket (the insect) goes to the doctor. The punchline is where the humor kicks in. It says the cricket had a "sticky" wicket situation and was feeling a little "bowled" over.\n\nThe wordplay comes from the fact that "wicket" and "bowled" are terms from the sport of cricket. In cricket, a wicket refers to the set of three stumps and two bails that a batsman defends. A "sticky wicket" is a phrase used to describe a difficult or precarious situation, often originating from the sport where a wet or damp wicket can make it challenging for batsmen to play.\n\nThe phrase "bowled over" is also a cricket term, where a batsman is dismissed when a ball knocks over their wicket. However, in a more general sense, "bowled over" is an idiomatic expression meaning to be overwhelmed, shocked, or surprised.\n\nIn the joke, the cricket (insect) is using these cricket (sport) terms to describe its situation. The humor comes from the unexpected twist of an insect using sports terminology to explain its predicament. The joke relies on a basic understanding of cricket terminology, but the wordplay and clever use of language create a lighthearted and amusing effect.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-f168-609f-8002-b6be26a2161d'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-07-19T09:15:49.949850+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-e65e-628f-8001-b169105f8b81'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'Cricket', 'joke': 'Why did the cricket go to the doctor?\n\nBecause it had a "sticky" wicket situation and was feeling a little "bowled" over! (get it?)'}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-e65e-628f-8001-b169105f8b81'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-07-19T09:15:48.792351+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-e498-6ee9-8000-8a0bba4aa45d'}}, tasks=(PregelTask(id='60839cba-9068-5569-987d-4a9dee0cc1df', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'A classic joke that combines wordplay with a dash of sports terminology. Here\'s a breakdown of the explanation:\n\nThe joke starts by setting up a familiar scenario: a cricket (the insect) goes to the doctor. The punchline is where the humor kicks in. It says the cricket had a "sticky" wicket situation and was feeling a little "bowled" over.\n\nThe wordplay comes from the fact that "wicket" and "bowled" are terms from the sport of cricket. In cricket, a wicket refers to the set of three stumps and two bails that a batsman defends. A "sticky wicket" is a phrase used to describe a difficult or precarious situation, often originating from the sport where a wet or damp wicket can make it challenging for batsmen to play.\n\nThe phrase "bowled over" is also a cricket term, where a batsman is dismissed when a ball knocks over their wicket. However, in a more general sense, "bowled over" is an idiomatic expression meaning to be overwhelmed, shocked, or surprised.\n\nIn the joke, the cricket (insect) is using these cricket (sport) terms to describe its situation. The humor comes from the unexpected twist of an insect using sports terminology to explain its predicament. The joke relies on a basic understanding of cricket terminology, but the wordplay and clever use of language create a lighthearted and amusing effect.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'Cricket'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-e498-6ee9-8000-8a0bba4aa45d'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-07-19T09:15:48.606731+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-e496-66fc-bfff-232af77ea444'}}, tasks=(PregelTask(id='6dbb367f-482a-19c5-231c-1ea3aadccc56', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the cricket go to the doctor?\n\nBecause it had a "sticky" wicket situation and was feeling a little "bowled" over! (get it?)'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-e496-66fc-bfff-232af77ea444'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-07-19T09:15:48.605710+00:00', parent_config=None, tasks=(PregelTask(id='bdc88217-8b3c-23d8-2b00-640b89783867', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'Cricket'}),), interrupts=())]

# %% [markdown]
# #### Updating State

# %%
workflow.update_state({"configurable": {"thread_id": "2", "checkpoint_id": "1f15d969-8ed6-683c-8000-0c7a2f030ccd", "checkpoint_ns": ""}}, {'topic':'Tenis'})
# Out:
# {'configurable': {'thread_id': '2',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f183558-6bed-628f-8000-5896ad146d3a'}}

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'Tenis'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f183558-6bed-628f-8000-5896ad146d3a'}}, metadata={'source': 'update', 'step': 0, 'parents': {}}, created_at='2026-07-19T09:37:58.130743+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f15d969-8ed6-683c-8000-0c7a2f030ccd'}}, tasks=(PregelTask(id='3a880357-800f-1293-3db1-aef3cd69f4e6', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
#  StateSnapshot(values={'topic': 'Tenis'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f183558-4573-6312-8000-846ff6ef7d86'}}, metadata={'source': 'update', 'step': 0, 'parents': {}}, created_at='2026-07-19T09:37:54.096195+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f15d969-8ed6-683c-8000-0c7a2f030ccd'}}, tasks=(PregelTask(id='58133712-29f6-9b16-1bf5-d02833ffba02', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
#  StateSnapshot(values={'topic': 'Tenis'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f183558-3116-60c3-8000-1570c19e2afd'}}, metadata={'source': 'update', 'step': 0, 'parents': {}}, created_at='2026-07-19T09:37:51.960893+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f15d969-8ed6-683c-8000-0c7a2f030ccd'}}, tasks=(PregelTask(id='18c152cc-9976-4110-22a3-9b18e837925d', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
#  StateSnapshot(values={'topic': 'Cricket', 'joke': 'Why did the cricket go to the doctor?\n\nBecause it had a "sticky" wicket situation and was feeling a little "bowled" over! (get it?)', 'explanation': 'A classic joke that combines wordplay with a dash of sports terminology. Here\'s a breakdown of the explanation:\n\nThe joke starts by setting up a familiar scenario: a cricket (the insect) goes to the doctor. The punchline is where the humor kicks in. It says the cricket had a "sticky" wicket situation and was feeling a little "bowled" over.\n\nThe wordplay comes from the fact that "wicket" and "bowled" are terms from the sport of cricket. In cricket, a wicket refers to the set of three stumps and two bails that a batsman defends. A "sticky wicket" is a phrase used to describe a difficult or precarious situation, often originating from the sport where a wet or damp wicket can make it challenging for batsmen to play.\n\nThe phrase "bowled over" is also a cricket term, where a batsman is dismissed when a ball knocks over their wicket. However, in a more general sense, "bowled over" is an idiomatic expression meaning to be overwhelmed, shocked, or surprised.\n\nIn the joke, the cricket (insect) is using these cricket (sport) terms to describe its situation. The humor comes from the unexpected twist of an insect using sports terminology to explain its predicament. The joke relies on a basic understanding of cricket terminology, but the wordplay and clever use of language create a lighthearted and amusing effect.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-f168-609f-8002-b6be26a2161d'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-07-19T09:15:49.949850+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-e65e-628f-8001-b169105f8b81'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'Cricket', 'joke': 'Why did the cricket go to the doctor?\n\nBecause it had a "sticky" wicket situation and was feeling a little "bowled" over! (get it?)'}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-e65e-628f-8001-b169105f8b81'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-07-19T09:15:48.792351+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-e498-6ee9-8000-8a0bba4aa45d'}}, tasks=(PregelTask(id='60839cba-9068-5569-987d-4a9dee0cc1df', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'A classic joke that combines wordplay with a dash of sports terminology. Here\'s a breakdown of the explanation:\n\nThe joke starts by setting up a familiar scenario: a cricket (the insect) goes to the doctor. The punchline is where the humor kicks in. It says the cricket had a "sticky" wicket situation and was feeling a little "bowled" over.\n\nThe wordplay comes from the fact that "wicket" and "bowled" are terms from the sport of cricket. In cricket, a wicket refers to the set of three stumps and two bails that a batsman defends. A "sticky wicket" is a phrase used to describe a difficult or precarious situation, often originating from the sport where a wet or damp wicket can make it challenging for batsmen to play.\n\nThe phrase "bowled over" is also a cricket term, where a batsman is dismissed when a ball knocks over their wicket. However, in a more general sense, "bowled over" is an idiomatic expression meaning to be overwhelmed, shocked, or surprised.\n\nIn the joke, the cricket (insect) is using these cricket (sport) terms to describe its situation. The humor comes from the unexpected twist of an insect using sports terminology to explain its predicament. The joke relies on a basic understanding of cricket terminology, but the wordplay and clever use of language create a lighthearted and amusing effect.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'Cricket'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-e498-6ee9-8000-8a0bba4aa45d'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-07-19T09:15:48.606731+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-e496-66fc-bfff-232af77ea444'}}, tasks=(PregelTask(id='6dbb367f-482a-19c5-231c-1ea3aadccc56', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the cricket go to the doctor?\n\nBecause it had a "sticky" wicket situation and was feeling a little "bowled" over! (get it?)'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f183526-e496-66fc-bfff-232af77ea444'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-07-19T09:15:48.605710+00:00', parent_config=None, tasks=(PregelTask(id='bdc88217-8b3c-23d8-2b00-640b89783867', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'Cricket'}),), interrupts=())]

# %% [markdown]
# ### Fault Tolerance

# %%
from langgraph.graph import StateGraph, END
from langgraph.checkpoint.memory import InMemorySaver
from typing import TypedDict
import time

# %%
# 1. Define the state
class CrashState(TypedDict):
    input: str
    step1: str
    step2: str

# %%
# 2. Define steps
def step_1(state: CrashState) -> CrashState:
    print("✅ Step 1 executed")
    return {"step1": "done", "input": state["input"]}

def step_2(state: CrashState) -> CrashState:
    print("⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)")
    time.sleep(30)  # Simulate long-running hang
    return {"step2": "done"}

def step_3(state: CrashState) -> CrashState:
    print("✅ Step 3 executed")
    return {"done": True}

# %%
# 3. Build the graph
builder = StateGraph(CrashState)
builder.add_node("step_1", step_1)
builder.add_node("step_2", step_2)
builder.add_node("step_3", step_3)

builder.set_entry_point("step_1")
builder.add_edge("step_1", "step_2")
builder.add_edge("step_2", "step_3")
builder.add_edge("step_3", END)

checkpointer = InMemorySaver()
graph = builder.compile(checkpointer=checkpointer)

# %%
try:
    print("▶️ Running graph: Please manually interrupt during Step 2...")
    graph.invoke({"input": "start"}, config={"configurable": {"thread_id": 'thread-1'}})
except KeyboardInterrupt:
    print("❌ Kernel manually interrupted (crash simulated).")
# Out:
# ▶️ Running graph: Please manually interrupt during Step 2...
# ✅ Step 1 executed
# ⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)
# ❌ Kernel manually interrupted (crash simulated).

# %%
# 6. Re-run to show fault-tolerant resume
print("\n🔁 Re-running the graph to demonstrate fault tolerance...")
final_state = graph.invoke(None, config={"configurable": {"thread_id": 'thread-1'}})
print("\n✅ Final State:", final_state)
# Out:
# 🔁 Re-running the graph to demonstrate fault tolerance...
# ⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)
# ✅ Step 3 executed
#
# ✅ Final State: {'input': 'start', 'step1': 'done', 'step2': 'done'}

# %%
list(graph.get_state_history({"configurable": {"thread_id": 'thread-1'}}))
# Out:
# [StateSnapshot(values={'input': 'start', 'step1': 'done', 'step2': 'done'}, next=(), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f18355c-f753-672d-8003-e339f1ab7578'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-07-19T09:40:00.122024+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f18355c-f750-6b4f-8002-1f86382d7e1e'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'input': 'start', 'step1': 'done', 'step2': 'done'}, next=('step_3',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f18355c-f750-6b4f-8002-1f86382d7e1e'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-07-19T09:40:00.120889+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f18355a-3775-602d-8001-01d24cf68e2a'}}, tasks=(PregelTask(id='24ff4d2b-62c8-c27d-612b-629427a058eb', name='step_3', path=('__pregel_pull', 'step_3'), error=None, interrupts=(), state=None, result={}),), interrupts=()),
#  StateSnapshot(values={'input': 'start', 'step1': 'done'}, next=('step_2',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f18355a-3775-602d-8001-01d24cf68e2a'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-07-19T09:38:46.316027+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f18355a-3773-61b0-8000-aeee5b5be0cc'}}, tasks=(PregelTask(id='7fa18f9e-6360-e6d6-2a88-39b70a34158f', name='step_2', path=('__pregel_pull', 'step_2'), error=None, interrupts=(), state=None, result={'step2': 'done'}),), interrupts=()),
#  StateSnapshot(values={'input': 'start'}, next=('step_1',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f18355a-3773-61b0-8000-aeee5b5be0cc'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-07-19T09:38:46.315246+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f18355a-3770-6ba7-bfff-c42dc608bf28'}}, tasks=(PregelTask(id='1e1ca8c5-612a-bc0a-21db-9880108ec3fc', name='step_1', path=('__pregel_pull', 'step_1'), error=None, interrupts=(), state=None, result={'step1': 'done', 'input': 'start'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f18355a-3770-6ba7-bfff-c42dc608bf28'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-07-19T09:38:46.314273+00:00', parent_config=None, tasks=(PregelTask(id='1bd92a3c-ee12-6308-bb41-86c64d724421', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'input': 'start'}),), interrupts=())]
