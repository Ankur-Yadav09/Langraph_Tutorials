# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langchain_community.tools import TavilySearchResults
from typing import TypedDict, Annotated
from langgraph.graph import add_messages, StateGraph, END
from dotenv import load_dotenv
from langgraph.prebuilt import ToolNode
from langchain_groq import ChatGroq

load_dotenv()

class AgentState(TypedDict):
    messages: Annotated[list, add_messages]

search_tool = TavilySearchResults(max_results=2)
tools = [search_tool]

llm = ChatGroq(model="llama-3.1-8b-instant")
llm_with_tools = llm.bind_tools(tools=tools)

def model(state: AgentState):
    return {
        "messages": [llm_with_tools.invoke(state["messages"])], 
    }

def tools_router(state: AgentState):
    last_message = state["messages"][-1]

    if(hasattr(last_message, "tool_calls") and len(last_message.tool_calls) > 0):
        return "tool_node"
    else: 
        return END
    

tool_node = ToolNode(tools=tools)

graph = StateGraph(AgentState)

graph.add_node("model", model)
graph.add_node("tool_node", tool_node)
graph.set_entry_point("model")

graph.add_conditional_edges("model", tools_router)
graph.add_edge("tool_node", "model")

app = graph.compile()

# %%
from IPython.display import Image, display
from langchain_core.runnables.graph import MermaidDrawMethod

display(
    Image(
        app.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API
        )
    )
)

# %%
input = {
    "messages": ["What's the current weather in Bangalore?"]
}

events = app.stream(input=input, stream_mode="values")

for event in events: 
    print(event["messages"])
# Out:
# [HumanMessage(content="What's the current weather in Bangalore?", additional_kwargs={}, response_metadata={}, id='14f6a454-8507-4584-8a1f-251342331580')]
# [HumanMessage(content="What's the current weather in Bangalore?", additional_kwargs={}, response_metadata={}, id='14f6a454-8507-4584-8a1f-251342331580'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'sz1pwc5ej', 'function': {'arguments': '{"query":"Bangalore current weather"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 286, 'total_tokens': 307, 'completion_time': 0.041861444, 'prompt_time': 0.020592234, 'queue_time': 0.052298146000000004, 'total_time': 0.062453678}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_8ab2e50475', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--ceb59c28-b476-4cf6-b059-eb2e7f0aa3bc-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'Bangalore current weather'}, 'id': 'sz1pwc5ej', 'type': 'tool_call'}], usage_metadata={'input_tokens': 286, 'output_tokens': 21, 'total_tokens': 307})]
# [HumanMessage(content="What's the current weather in Bangalore?", additional_kwargs={}, response_metadata={}, id='14f6a454-8507-4584-8a1f-251342331580'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'sz1pwc5ej', 'function': {'arguments': '{"query":"Bangalore current weather"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 286, 'total_tokens': 307, 'completion_time': 0.041861444, 'prompt_time': 0.020592234, 'queue_time': 0.052298146000000004, 'total_time': 0.062453678}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_8ab2e50475', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--ceb59c28-b476-4cf6-b059-eb2e7f0aa3bc-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'Bangalore current weather'}, 'id': 'sz1pwc5ej', 'type': 'tool_call'}], usage_metadata={'input_tokens': 286, 'output_tokens': 21, 'total_tokens': 307}), ToolMessage(content='[{"title": "Bengaluru weather forecast: Mild temperatures with scattered showers", "url": "https://timesofindia.indiatimes.com/city/bengaluru/bangalore-weather-forecast-enjoy-a-mix-of-sunshine-and-showers-with-temperature-comforts/articleshow/122474139.cms", "content": "TOI logo\\n\\n## TOI\\n\\n# Bengaluru weather forecast: Mild temperatures with scattered showers - July 15, 2025\\n\\nBengaluru weather forecast: Mild temperatures with scattered showers - July 15, 2025\\n\\n### Upcoming Week\'s Outlook\\n\\n### Impact and Planning\\n\\n## Visual Stories\\n\\nWhat makes Neon Tetra the most popular aquarium fish in 2025\\n\\n10 quotes from Andrea Gibson poems that capture the joy of tender living\\n\\nAnju Kurian slays in style\\n\\nAnjali Aroraâ\x80\x99s Best Ethnic and Casual Style Moments [...] Numerology Predictions Today, July 15, 2025: Read your personalized forecast for numbers 1 to 9\\n10 Countries besides India that experience the monsoon season\\n5 real-life animals that depend on blood diet\\nTripti Dimri-inspired blouse designs to elevate your festive style [...] Famous Hollywood plots retold through Bollywood\'s lens\\n\\nInflammation alert: 10 foods that might be making you feel worse\\n\\nHelly Shah Channels Cool, Classy & Colourful Vibes\\n\\n6 science-backed ways for students to calm their mind before an exam\\n\\n10 baby girl names that mean sparkle\\n\\n9 unforgettable Mr. Bean moments to help students push through tough days\\n\\n## Photostories", "score": 0.9104262}, {"title": "Bangalore weather in July 2025 - Weather25.com", "url": "https://www.weather25.com/asia/india/karnataka/bangalore?page=month&month=July", "content": "| 27 Patchy rain possible 23° /19° | 28 Patchy rain possible 26° /19° | 29 Cloudy 27° /21° | 30 Overcast 28° /20° | 31 Patchy rain possible 27° /20° |  |  | [...] | Sun | Mon | Tue | Wed | Thu | Fri | Sat |\\n| --- | --- | --- | --- | --- | --- | --- |\\n|  |  | 1 Light rain shower 28° /21° | 2 Patchy rain possible 28° /21° | 3 Partly cloudy 26° /21° | 4 Light rain shower 27° /20° | 5 Patchy rain possible 26° /20° | [...] The weather in Bangalore in July is hot. The average temperatures are between 20°C and 28°C.\\n\\nYou can expect rain for roughly half of the month of July in Bangalore. We’re expecting roughly 8 to 15 days of rain, so your rubber boots and umbrella are going to see plenty of use this month if you’re keen on staying dry.\\n\\nOur weather forecast can give you a great sense of what weather to expect in Bangalore in July 2025.", "score": 0.8773195}]', name='tavily_search_results_json', id='7ec81eb4-5ac0-4579-9655-e88d4ed31de9', tool_call_id='sz1pwc5ej', artifact={'query': 'Bangalore current weather', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://timesofindia.indiatimes.com/city/bengaluru/bangalore-weather-forecast-enjoy-a-mix-of-sunshine-and-showers-with-temperature-comforts/articleshow/122474139.cms', 'title': 'Bengaluru weather forecast: Mild ...
# [HumanMessage(content="What's the current weather in Bangalore?", additional_kwargs={}, response_metadata={}, id='14f6a454-8507-4584-8a1f-251342331580'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'sz1pwc5ej', 'function': {'arguments': '{"query":"Bangalore current weather"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 286, 'total_tokens': 307, 'completion_time': 0.041861444, 'prompt_time': 0.020592234, 'queue_time': 0.052298146000000004, 'total_time': 0.062453678}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_8ab2e50475', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--ceb59c28-b476-4cf6-b059-eb2e7f0aa3bc-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'Bangalore current weather'}, 'id': 'sz1pwc5ej', 'type': 'tool_call'}], usage_metadata={'input_tokens': 286, 'output_tokens': 21, 'total_tokens': 307}), ToolMessage(content='[{"title": "Bengaluru weather forecast: Mild temperatures with scattered showers", "url": "https://timesofindia.indiatimes.com/city/bengaluru/bangalore-weather-forecast-enjoy-a-mix-of-sunshine-and-showers-with-temperature-comforts/articleshow/122474139.cms", "content": "TOI logo\\n\\n## TOI\\n\\n# Bengaluru weather forecast: Mild temperatures with scattered showers - July 15, 2025\\n\\nBengaluru weather forecast: Mild temperatures with scattered showers - July 15, 2025\\n\\n### Upcoming Week\'s Outlook\\n\\n### Impact and Planning\\n\\n## Visual Stories\\n\\nWhat makes Neon Tetra the most popular aquarium fish in 2025\\n\\n10 quotes from Andrea Gibson poems that capture the joy of tender living\\n\\nAnju Kurian slays in style\\n\\nAnjali Aroraâ\x80\x99s Best Ethnic and Casual Style Moments [...] Numerology Predictions Today, July 15, 2025: Read your personalized forecast for numbers 1 to 9\\n10 Countries besides India that experience the monsoon season\\n5 real-life animals that depend on blood diet\\nTripti Dimri-inspired blouse designs to elevate your festive style [...] Famous Hollywood plots retold through Bollywood\'s lens\\n\\nInflammation alert: 10 foods that might be making you feel worse\\n\\nHelly Shah Channels Cool, Classy & Colourful Vibes\\n\\n6 science-backed ways for students to calm their mind before an exam\\n\\n10 baby girl names that mean sparkle\\n\\n9 unforgettable Mr. Bean moments to help students push through tough days\\n\\n## Photostories", "score": 0.9104262}, {"title": "Bangalore weather in July 2025 - Weather25.com", "url": "https://www.weather25.com/asia/india/karnataka/bangalore?page=month&month=July", "content": "| 27 Patchy rain possible 23° /19° | 28 Patchy rain possible 26° /19° | 29 Cloudy 27° /21° | 30 Overcast 28° /20° | 31 Patchy rain possible 27° /20° |  |  | [...] | Sun | Mon | Tue | Wed | Thu | Fri | Sat |\\n| --- | --- | --- | --- | --- | --- | --- |\\n|  |  | 1 Light rain shower 28° /21° | 2 Patchy rain possible 28° /21° | 3 Partly cloudy 26° /21° | 4 Light rain shower 27° /20° | 5 Patchy rain possible 26° /20° | [...] The weather in Bangalore in July is hot. The average temperatures are between 20°C and 28°C.\\n\\nYou can expect rain for roughly half of the month of July in Bangalore. We’re expecting roughly 8 to 15 days of rain, so your rubber boots and umbrella are going to see plenty of use this month if you’re keen on staying dry.\\n\\nOur weather forecast can give you a great sense of what weather to expect in Bangalore in July 2025.", "score": 0.8773195}]', name='tavily_search_results_json', id='7ec81eb4-5ac0-4579-9655-e88d4ed31de9', tool_call_id='sz1pwc5ej', artifact={'query': 'Bangalore current weather', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://timesofindia.indiatimes.com/city/bengaluru/bangalore-weather-forecast-enjoy-a-mix-of-sunshine-and-showers-with-temperature-comforts/articleshow/122474139.cms', 'title': 'Bengaluru weather forecast: Mild ...

# %%
input = {
    "messages": ["What's the current weather in Bangalore?"]
}

events = app.stream(input=input, stream_mode="updates")

for event in events: 
    print(event)
# Out:
# {'model': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'n57aeyq70', 'function': {'arguments': '{"query":"Bangalore current weather"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 286, 'total_tokens': 307, 'completion_time': 0.034761251, 'prompt_time': 0.020477754, 'queue_time': 0.049163896, 'total_time': 0.055239005}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_8ab2e50475', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--660adf73-b5f1-4bcd-9863-254185ee8f5c-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'Bangalore current weather'}, 'id': 'n57aeyq70', 'type': 'tool_call'}], usage_metadata={'input_tokens': 286, 'output_tokens': 21, 'total_tokens': 307})]}}
# {'tool_node': {'messages': [ToolMessage(content='[{"title": "Bengaluru weather forecast: Mild temperatures with scattered showers", "url": "https://timesofindia.indiatimes.com/city/bengaluru/bangalore-weather-forecast-enjoy-a-mix-of-sunshine-and-showers-with-temperature-comforts/articleshow/122474139.cms", "content": "TOI logo\\n\\n## TOI\\n\\n# Bengaluru weather forecast: Mild temperatures with scattered showers - July 15, 2025\\n\\nBengaluru weather forecast: Mild temperatures with scattered showers - July 15, 2025\\n\\n### Upcoming Week\'s Outlook\\n\\n### Impact and Planning\\n\\n## Visual Stories\\n\\nWhat makes Neon Tetra the most popular aquarium fish in 2025\\n\\n10 quotes from Andrea Gibson poems that capture the joy of tender living\\n\\nAnju Kurian slays in style\\n\\nAnjali Aroraâ\x80\x99s Best Ethnic and Casual Style Moments [...] Numerology Predictions Today, July 15, 2025: Read your personalized forecast for numbers 1 to 9\\n10 Countries besides India that experience the monsoon season\\n5 real-life animals that depend on blood diet\\nTripti Dimri-inspired blouse designs to elevate your festive style [...] Famous Hollywood plots retold through Bollywood\'s lens\\n\\nInflammation alert: 10 foods that might be making you feel worse\\n\\nHelly Shah Channels Cool, Classy & Colourful Vibes\\n\\n6 science-backed ways for students to calm their mind before an exam\\n\\n10 baby girl names that mean sparkle\\n\\n9 unforgettable Mr. Bean moments to help students push through tough days\\n\\n## Photostories", "score": 0.9104262}, {"title": "Bangalore weather in July 2025 - Weather25.com", "url": "https://www.weather25.com/asia/india/karnataka/bangalore?page=month&month=July", "content": "| 27 Patchy rain possible 23° /19° | 28 Patchy rain possible 26° /19° | 29 Cloudy 27° /21° | 30 Overcast 28° /20° | 31 Patchy rain possible 27° /20° |  |  | [...] | Sun | Mon | Tue | Wed | Thu | Fri | Sat |\\n| --- | --- | --- | --- | --- | --- | --- |\\n|  |  | 1 Light rain shower 28° /21° | 2 Patchy rain possible 28° /21° | 3 Partly cloudy 26° /21° | 4 Light rain shower 27° /20° | 5 Patchy rain possible 26° /20° | [...] The weather in Bangalore in July is hot. The average temperatures are between 20°C and 28°C.\\n\\nYou can expect rain for roughly half of the month of July in Bangalore. We’re expecting roughly 8 to 15 days of rain, so your rubber boots and umbrella are going to see plenty of use this month if you’re keen on staying dry.\\n\\nOur weather forecast can give you a great sense of what weather to expect in Bangalore in July 2025.", "score": 0.8773195}]', name='tavily_search_results_json', id='ecddf7ae-c9b7-40ad-8f6a-d3ad34fe39cb', tool_call_id='n57aeyq70', artifact={'query': 'Bangalore current weather', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://timesofindia.indiatimes.com/city/bengaluru/bangalore-weather-forecast-enjoy-a-mix-of-sunshine-and-showers-with-temperature-comforts/articleshow/122474139.cms', 'title': 'Bengaluru weather forecast: Mild temperatures with scattered showers', 'content': "TOI logo\n\n## TOI\n\n# Bengaluru weather forecast: Mild temperatures with scattered showers - July 15, 2025\n\nBengaluru weather forecast: Mild temperatures with scattered showers - July 15, 2025\n\n### Upcoming Week's Outlook\n\n### Impact and Planning\n\n## Visual Stories\n\nWhat makes Neon Tetra the most popular aquarium fish in 2025\n\n10 quotes from Andrea Gibson poems that capture the joy of tender living\n\nAnju Kurian slays in style\n\nAnjali Aroraâ\x80\x99s Best Ethnic and Casual Style Moments [...] Numerology Predictions Today, July 15, 2025: Read your personalized forecast for numbers 1 to 9\n10 Countries besides India that experience the monsoon season\n5 real-life animals that depend on blood diet\nTripti Dimri-inspired blouse designs to elevate your festive style [...] Famous Hollywood plots retold through Bollywood's lens\n\nInflammation alert: 10 foods that might be making you ...
# {'model': {'messages': [AIMessage(content='The current weather in Bangalore is mild with scattered showers. The temperature is expected to be around 20-28°C, with a chance of rain for roughly half of the month of July.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 39, 'prompt_tokens': 1003, 'total_tokens': 1042, 'completion_time': 0.07465604, 'prompt_time': 0.063491781, 'queue_time': 0.052613568, 'total_time': 0.138147821}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_510c177af0', 'finish_reason': 'stop', 'logprobs': None}, id='run--76d78205-c660-4cf9-a915-463a9b9e8993-0', usage_metadata={'input_tokens': 1003, 'output_tokens': 39, 'total_tokens': 1042})]}}

# %%
input = {
    "messages": ["Hi, how are you?"]
}

events = app.astream_events(input=input, version="v2")

async for event in events: 
    print(event)
# Out:
# {'event': 'on_chain_start', 'data': {'input': {'messages': ['Hi, how are you?']}}, 'name': 'LangGraph', 'tags': [], 'run_id': '7610e938-86a4-485c-9f0d-a42fc2b8296f', 'metadata': {}, 'parent_ids': []}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='ec4d9ba4-771c-46d8-993b-7ea56986cb11')]}}, 'name': 'model', 'tags': ['graph:step:1'], 'run_id': '64b5e24b-7730-4efe-96ad-917ca0f8b899', 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d'}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f']}
# {'event': 'on_chat_model_start', 'data': {'input': {'messages': [[HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='ec4d9ba4-771c-46d8-993b-7ea56986cb11')]]}}, 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'run_id': 'f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f', '64b5e24b-7730-4efe-96ad-917ca0f8b899']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450')}, 'run_id': 'f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f', '64b5e24b-7730-4efe-96ad-917ca0f8b899']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='I', additional_kwargs={}, response_metadata={}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450')}, 'run_id': 'f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f', '64b5e24b-7730-4efe-96ad-917ca0f8b899']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content="'m", additional_kwargs={}, response_metadata={}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450')}, 'run_id': 'f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f', '64b5e24b-7730-4efe-96ad-917ca0f8b899']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' functioning', additional_kwargs={}, response_metadata={}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450')}, 'run_id': 'f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f', '64b5e24b-7730-4efe-96ad-917ca0f8b899']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' properly', additional_kwargs={}, response_metadata={}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450')}, 'run_id': 'f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f', '64b5e24b-7730-4efe-96ad-917ca0f8b899']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450')}, 'run_id': 'f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f', '64b5e24b-7730-4efe-96ad-917ca0f8b899']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' thanks', additional_kwargs={}, response_metadata={}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450')}, 'run_id': 'f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f', '64b5e24b-7730-4efe-96ad-917ca0f8b899']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' for', additional_kwargs={}, response_metadata={}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450')}, 'run_id': 'f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f', '64b5e24b-7730-4efe-96ad-917ca0f8b899']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' asking', additional_kwargs={}, response_metadata={}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450')}, 'run_id': 'f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f', '64b5e24b-7730-4efe-96ad-917ca0f8b899']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450')}, 'run_id': 'f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f', '64b5e24b-7730-4efe-96ad-917ca0f8b899']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' Is', additional_kwargs={}, response_metadata={}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450')}, 'run_id': 'f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f', '64b5e24b-7730-4efe-96ad-917ca0f8b899']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' there', additional_kwargs={}, response_metadata={}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450')}, 'run_id': 'f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f', '64b5e24b-7730-4efe-96ad-917ca0f8b899']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' anything', additional_kwargs={}, response_metadata={}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450')}, 'run_id': 'f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f', '64b5e24b-7730-4efe-96ad-917ca0f8b899']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' I', additional_kwargs={}, response_metadata={}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450')}, 'run_id': 'f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f', '64b5e24b-7730-4efe-96ad-917ca0f8b899']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' can', additional_kwargs={}, response_metadata={}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450')}, 'run_id': 'f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f', '64b5e24b-7730-4efe-96ad-917ca0f8b899']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' assist', additional_kwargs={}, response_metadata={}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450')}, 'run_id': 'f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f', '64b5e24b-7730-4efe-96ad-917ca0f8b899']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' you', additional_kwargs={}, response_metadata={}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450')}, 'run_id': 'f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f', '64b5e24b-7730-4efe-96ad-917ca0f8b899']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' with', additional_kwargs={}, response_metadata={}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450')}, 'run_id': 'f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f', '64b5e24b-7730-4efe-96ad-917ca0f8b899']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='?', additional_kwargs={}, response_metadata={}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450')}, 'run_id': 'f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f', '64b5e24b-7730-4efe-96ad-917ca0f8b899']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_8ab2e50475'}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', usage_metadata={'input_tokens': 284, 'output_tokens': 19, 'total_tokens': 303})}, 'run_id': 'f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f', '64b5e24b-7730-4efe-96ad-917ca0f8b899']}
# {'event': 'on_chat_model_end', 'data': {'output': AIMessage(content="I'm functioning properly, thanks for asking. Is there anything I can assist you with?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_8ab2e50475'}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', usage_metadata={'input_tokens': 284, 'output_tokens': 19, 'total_tokens': 303}), 'input': {'messages': [[HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='ec4d9ba4-771c-46d8-993b-7ea56986cb11')]]}}, 'run_id': 'f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7, 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'LANGSMITH_PROJECT': 'pr-drab-bassoon-82', 'LANGSMITH_TRACING': 'true'}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f', '64b5e24b-7730-4efe-96ad-917ca0f8b899']}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='ec4d9ba4-771c-46d8-993b-7ea56986cb11'), AIMessage(content="I'm functioning properly, thanks for asking. Is there anything I can assist you with?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_8ab2e50475'}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', usage_metadata={'input_tokens': 284, 'output_tokens': 19, 'total_tokens': 303})]}}, 'name': 'tools_router', 'tags': ['seq:step:3'], 'run_id': '852f6096-ab52-47a6-8c21-f40247b6d330', 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d'}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f', '64b5e24b-7730-4efe-96ad-917ca0f8b899']}
# {'event': 'on_chain_end', 'data': {'output': '__end__', 'input': {'messages': [HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='ec4d9ba4-771c-46d8-993b-7ea56986cb11'), AIMessage(content="I'm functioning properly, thanks for asking. Is there anything I can assist you with?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_8ab2e50475'}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', usage_metadata={'input_tokens': 284, 'output_tokens': 19, 'total_tokens': 303})]}}, 'run_id': '852f6096-ab52-47a6-8c21-f40247b6d330', 'name': 'tools_router', 'tags': ['seq:step:3'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'LANGSMITH_PROJECT': 'pr-drab-bassoon-82', 'LANGSMITH_TRACING': 'true'}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f', '64b5e24b-7730-4efe-96ad-917ca0f8b899']}
# {'event': 'on_chain_stream', 'run_id': '64b5e24b-7730-4efe-96ad-917ca0f8b899', 'name': 'model', 'tags': ['graph:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d'}, 'data': {'chunk': {'messages': [AIMessage(content="I'm functioning properly, thanks for asking. Is there anything I can assist you with?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_8ab2e50475'}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', usage_metadata={'input_tokens': 284, 'output_tokens': 19, 'total_tokens': 303})]}}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [AIMessage(content="I'm functioning properly, thanks for asking. Is there anything I can assist you with?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_8ab2e50475'}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', usage_metadata={'input_tokens': 284, 'output_tokens': 19, 'total_tokens': 303})]}, 'input': {'messages': [HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='ec4d9ba4-771c-46d8-993b-7ea56986cb11')]}}, 'run_id': '64b5e24b-7730-4efe-96ad-917ca0f8b899', 'name': 'model', 'tags': ['graph:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:8126747f-05ef-6d0f-83cb-8a69cec6730d', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'LANGSMITH_PROJECT': 'pr-drab-bassoon-82', 'LANGSMITH_TRACING': 'true'}, 'parent_ids': ['7610e938-86a4-485c-9f0d-a42fc2b8296f']}
# {'event': 'on_chain_stream', 'run_id': '7610e938-86a4-485c-9f0d-a42fc2b8296f', 'name': 'LangGraph', 'tags': [], 'metadata': {}, 'data': {'chunk': {'model': {'messages': [AIMessage(content="I'm functioning properly, thanks for asking. Is there anything I can assist you with?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_8ab2e50475'}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', usage_metadata={'input_tokens': 284, 'output_tokens': 19, 'total_tokens': 303})]}}}, 'parent_ids': []}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='ec4d9ba4-771c-46d8-993b-7ea56986cb11'), AIMessage(content="I'm functioning properly, thanks for asking. Is there anything I can assist you with?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_8ab2e50475'}, id='run--f63448ed-50af-4a8f-bd6a-1ddcb3ca2450', usage_metadata={'input_tokens': 284, 'output_tokens': 19, 'total_tokens': 303})]}}, 'run_id': '7610e938-86a4-485c-9f0d-a42fc2b8296f', 'name': 'LangGraph', 'tags': [], 'metadata': {}, 'parent_ids': []}

# %%
input = {
    "messages": ["Hi, how are you?"]
}

events = app.astream_events(input=input, version="v2")

async for event in events: 
    if event["event"] == "on_chat_model_stream":
        print(event["data"]["chunk"].content, end="", flush=True)
# Out:
# I'm functioning properly, thank you for asking. What would you like to talk about or search for today?
